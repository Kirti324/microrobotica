# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Questo è il nostro primo notebook
# (titolo di livello più alto con #)
# In questo notebook vedremo e nozione base
#
# Questa cella è scritta in *MarkDown* eccon un esempio di **grasetto**
# ![Screenshot 2025-09-12 212348.png](attachment:13847257-46e5-440f-b088-9f9d1df0dff9.png)

# %% [markdown]
# In *MarkDonw* è semplice scrivere equazioni, per esempio:
# $f(x) = \frac(sin(x)}{x)$

# %% [markdown]
# # Pelicolo nell'uso dei notebook
# se si cancella una cella, la variabile rimane, bisogna fare restart kernel

# %%
a = 1

# %%
a
# Out:
# 1

# %% [markdown]
# # Ripasso vario su Python

# %% [markdown]
# 1) generare una stringa di testo casuale di lunghezza asegnata, la stringa può contenere lettere, numeri, spazi, simboli di punteggiatura.

# %%
import random

# %%
lenght = 20
#il metodo join è un metodo delle stringhe! Però vuole com eparametro una lista di stringhe
string = "".join([chr(random.randint(0, 255)) for _ in range(lenght)])
print(string)
# Out:
# m[¯ø	yKû½Ò¹ß9+z2y¦

# %%
chars = "qwertyuiopasdfghjklzxcvbnm 123456789,.-!?^"
string = "".join([random.choice(chars) for _ in range(lenght)])
print(string)
# Out:
# fp9.49o5h1cx z7pxdvp

# %% [markdown]
# ## Compito
# * cercate un testo letterario in formato .txt.
# * leggete in file.
# * Create un dizionario che ha come chiavi tutti i caratteri presenti nel file .txt e come valore la frequenza assoluta del carattere nel testo
# * Creata un dizionario che ha come chiavi tutti i caratteri presenti nel file .txt e come valori delle list. La lista contiene tutti i caratteri successori della lettera usata come chiave. Va bene che la lista contiene doppioni.

# %% [markdown]
# ## Ripasso cicli

# %%
l1, l2 =[1, 2, 3, 4], ["a", "b", "c", "d", "e"]

# %% [markdown]
# zip permette di fare un ciclo in parallelo su due o più colezioni

# %%
#for v in l1:
#for i, v in enumerate(l1):
for v1, v2 in zip(l1,l2):
    print(v1, v2)
# Out:
# 1 a
# 2 b
# 3 c
# 4 d

# %%
import random

# %%
lettere = "abcdefghilmnstuvz"
# e' un metodo delle stringhe
d = {i:"".join(random.choices(lettere,k=20)) 
                             for i in range(5)}
d
# Out:
# {0: 'beiammenungivhfbthca',
#  1: 'dacgddnlvcedaluindib',
#  2: 'imlaidteazagcgdhulhh',
#  3: 'nffzdefscsiedhvazaeb',
#  4: 'esavfcbbtvctnettummu'}

# %%
def findChar(text, char):
    """
    La funzione ritorna True se la funzione é presente in text, False altrimenti
    """
    return char in text

# %%
# nome funzione    parametri   return
findchar =  lambda text, char: char in text

# %%
d_a = {i:findchar(d[i],"a") for i in d}
d_a
# Out:
# {0: True, 1: True, 2: True, 3: True, 4: True}

# %% [markdown]
# ## In Pyhton tutto è un oggetto, anche le funzioni

# %%
somma = lambda a, b: a+b
prodotto = lambda a, b: a*b
operazioni = {"+": somma, "*": prodotto}

# %%
operazioni
# Out:
# {'+': <function __main__.<lambda>(a, b)>,
#  '*': <function __main__.<lambda>(a, b)>}

# %%
op = input("Inserisci + per la sommma e * per il prodotto -> ")
a =  float(input("Inserisci il primo numero -> "))
b =  float(input("Inserisci il secondo numero -> "))

if op in operazioni:
    print(operazioni[op](a, b))
else:
    print("Operazione non valida")
# Out:
# Inserisci + per la sommma e * per il prodotto ->  +
# Inserisci il primo numero ->  2
# Inserisci il secondo numero ->  2
# 4.0

# %%
l = list(range(10))
print(l[::3])
print(l[::-3])
# Out:
# [0, 3, 6, 9]
# [9, 6, 3, 0]
